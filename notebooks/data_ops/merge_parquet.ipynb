# %%
import pandas as pd
import os
window_size = 8
tag_type = "tag"
dataset_paths = [
    '/nas/mars/dataset/LongVideoBench',
    '/nas/mars/dataset/MLVU',
    '/nas/mars/dataset/LVBench',
    '/nas/mars/dataset/Video-MME'
]

train_datasets = ["/nas/mars/dataset/LongVideoBench/",  "/nas/mars/dataset/LVBench/", "/nas/mars/dataset/Video-MME/"]
test_datasets = ["/nas/mars/dataset/MLVU/"]

training_paths = []
for dataset_path in train_datasets:
    data_path = os.path.join(dataset_path, f"window_{window_size}", f"{tag_type}")
    for file in os.listdir(data_path):
        if file.endswith(".parquet"):
            training_paths.append(os.path.join(data_path, file))  
            print("Training Path: ", os.path.join(data_path, file) ) 
test_paths = []
for dataset_path in test_datasets:
    data_path = os.path.join(dataset_path, f"window_{window_size}", f"{tag_type}")
    for file in os.listdir(data_path):
        if file.endswith(".parquet"):
            test_paths.append(os.path.join(data_path, file))
            print("Test Path: ", os.path.join(data_path, file) )
train_dfs = []
total_rows = 0

for path in training_paths:
    df = pd.read_parquet(path)
    print("Path: ", path, "Shape: ", df.shape)
    # map extra_info.index to between total_rows and total_rows + df.shape[0]
    # update extra_info['correct_choice'] to be a string
    df['extra_info'] = df['extra_info'].apply(lambda x: {**x, 'correct_choice': str(x['correct_choice'])})
    df['extra_info'] = df['extra_info'].apply(lambda x: {**x, 'index': x['index'] + total_rows})
    train_dfs.append(df)
    total_rows += df.shape[0]
    
train_dfs = pd.concat(train_dfs)
if not os.path.exists(f"/nas/mars/vseek/data/{tag_type}"):
    os.makedirs(f"/nas/mars/vseek/data/{tag_type}")
full_train_parquet = f"/nas/mars/vseek/data/{tag_type}/train.parquet"
train_dfs.to_parquet(full_train_parquet)


for path in test_paths:
    df = pd.read_parquet(path)
    print("Path: ", path, "Shape: ", df.shape)
    test_dfs.append(df)
    
test_dfs = pd.concat(test_dfs)
if not os.path.exists(f"/nas/mars/vseek/data/{tag_type}"):
    os.makedirs(f"/nas/mars/vseek/data/{tag_type}")
full_test_parquet = f"/nas/mars/vseek/data/{tag_type}/test.parquet"
test_dfs.to_parquet(full_test_parquet)
# Out:
# Training Path:  /nas/mars/dataset/LongVideoBench/window_8/tag/test.parquet
# Training Path:  /nas/mars/dataset/LongVideoBench/window_8/tag/train.parquet
# Training Path:  /nas/mars/dataset/LVBench/window_8/tag/test.parquet
# Training Path:  /nas/mars/dataset/LVBench/window_8/tag/train.parquet
# Training Path:  /nas/mars/dataset/Video-MME/window_8/tag/test.parquet
# Training Path:  /nas/mars/dataset/Video-MME/window_8/tag/train.parquet
# Test Path:  /nas/mars/dataset/MLVU/window_8/tag/test.parquet
# Test Path:  /nas/mars/dataset/MLVU/window_8/tag/train.parquet
# Path:  /nas/mars/dataset/LongVideoBench/window_8/tag/test.parquet Shape:  (268, 5)
# Path:  /nas/mars/dataset/LongVideoBench/window_8/tag/train.parquet Shape:  (1069, 5)
# Path:  /nas/mars/dataset/LVBench/window_8/tag/test.parquet Shape:  (310, 5)
# Path:  /nas/mars/dataset/LVBench/window_8/tag/train.parquet Shape:  (1239, 5)
# Path:  /nas/mars/dataset/Video-MME/window_8/tag/test.parquet Shape:  (540, 5)
# Path:  /nas/mars/dataset/Video-MME/window_8/tag/train.parquet Shape:  (2160, 5)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 44
#      42 train_dfs = pd.concat(train_dfs)
#      43 full_train_parquet = f"/nas/mars/vseek/data/{tag_type}/train.parquet"
# ---> 44 train_dfs.to_parquet(full_train_parquet)
#      47 for path in test_paths:
#      48     df = pd.read_parquet(path)
#
# File ~/anaconda3/envs/vseek-vllm/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/vseek-vllm/lib/python3.11/site-packages/pandas/core/frame.py:3124, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3043 """
#    3044 Write a DataFrame to the binary parquet format.
#    3045
#    (...)   3120 >>> content = f.read()
#    3121 """
#    3122 from pandas.io.parquet import to_parquet
# -> 3124 return to_parquet(
#    3125     self,
#    3126     path,
#    3127     engine,
#    3128     compression=compression,
#    3129     index=index,
#    3130     partition_cols=partition_cols,
#    3131     storage_options=storage_options,
#    3132     **kwargs,
#    3133 )
#
# File ~/anaconda3/envs/vseek-vllm/lib/python3.11/site-packages/pandas/io/parquet.py:482, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     478 impl = get_engine(engine)
#     480 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 482 impl.write(
#     483     df,
#     484     path_or_buf,
#     485     compression=compression,
#     486     index=index,
#     487     partition_cols=partition_cols,
#     488     storage_options=storage_options,
#     489     filesystem=filesystem,
#     490     **kwargs,
#     491 )
#     493 if path is None:
#     494     assert isinstance(path_or_buf, io.BytesIO)
#
# File ~/anaconda3/envs/vseek-vllm/lib/python3.11/site-packages/pandas/io/parquet.py:199, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     196     merged_metadata = {**existing_metadata, **df_metadata}
#     197     table = table.replace_schema_metadata(merged_metadata)
# --> 199 path_or_handle, handles, filesystem = _get_path_or_handle(
#     200     path,
#     201     filesystem,
#     202     storage_options=storage_options,
#     203     mode="wb",
#     204     is_dir=partition_cols is not None,
#     205 )
#     206 if (
#     207     isinstance(path_or_handle, io.BufferedWriter)
#     208     and hasattr(path_or_handle, "name")
#     209     and isinstance(path_or_handle.name, (str, bytes))
#     210 ):
#     211     if isinstance(path_or_handle.name, bytes):
#
# File ~/anaconda3/envs/vseek-vllm/lib/python3.11/site-packages/pandas/io/parquet.py:141, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     131 handles = None
#     132 if (
#     133     not fs
#     134     and not is_dir
#    (...)    139     # fsspec resources can also point to directories
#     140     # this branch is used for example when reading from non-fsspec URLs
# --> 141     handles = get_handle(
#     142         path_or_handle, mode, is_text=False, storage_options=storage_options
#     143     )
#     144     fs = None
#     145     path_or_handle = handles.handle
#
# File ~/anaconda3/envs/vseek-vllm/lib/python3.11/site-packages/pandas/io/common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~/anaconda3/envs/vseek-vllm/lib/python3.11/site-packages/pandas/io/common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '/nas/mars/vseek/data/tag'

# %%
import pandas as pd

train = pd.read_parquet("/nas/mars/vseek/data/tagsummary/train.parquet")
test = pd.read_parquet("/nas/mars/vseek/data/tagsummary/test.parquet")
print(train.shape)
print(test.shape)
# Out:
# ---------------------------------------------------------------------------
# ArrowNotImplementedError                  Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 train = pd.read_parquet("/nas/mars/vseek/data/tagsummary/train.parquet")
#       4 test = pd.read_parquet("/nas/mars/vseek/data/tagsummary/test.parquet")
#       5 print(train.shape)
#
# File ~/anaconda3/envs/vseek-vllm/lib/python3.11/site-packages/pandas/io/parquet.py:669, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     666     use_nullable_dtypes = False
#     667 check_dtype_backend(dtype_backend)
# --> 669 return impl.read(
#     670     path,
#     671     columns=columns,
#     672     filters=filters,
#     673     storage_options=storage_options,
#     674     use_nullable_dtypes=use_nullable_dtypes,
#     675     dtype_backend=dtype_backend,
#     676     filesystem=filesystem,
#     677     **kwargs,
#     678 )
#
# File ~/anaconda3/envs/vseek-vllm/lib/python3.11/site-packages/pandas/io/parquet.py:265, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     258 path_or_handle, handles, filesystem = _get_path_or_handle(
#     259     path,
#     260     filesystem,
#     261     storage_options=storage_options,
#     262     mode="rb",
#     263 )
#     264 try:
# --> 265     pa_table = self.api.parquet.read_table(
#     266         path_or_handle,
#     267         columns=columns,
#     268         filesystem=filesystem,
#     269         filters=filters,
#     270         **kwargs,
#     271     )
#     273     with catch_warnings():
#     274         filterwarnings(
#     275             "ignore",
#     276             "make_block is deprecated",
#     277             DeprecationWarning,
#     278         )
#
# File ~/anaconda3/envs/vseek-vllm/lib/python3.11/site-packages/pyarrow/parquet/core.py:1898, in read_table(source, columns, use_threads, schema, use_pandas_metadata, read_dictionary, binary_type, list_type, memory_map, buffer_size, partitioning, filesystem, filters, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, page_checksum_verification, arrow_extensions_enabled)
#    1884     # TODO test that source is not a directory or a list
#    1885     dataset = ParquetFile(
#    1886         source, read_dictionary=read_dictionary,
#    1887         binary_type=binary_type,
#    (...)   1895         page_checksum_verification=page_checksum_verification,
#    1896     )
# -> 1898 return dataset.read(columns=columns, use_threads=use_threads,
#    1899                     use_pandas_metadata=use_pandas_metadata)
#
# File ~/anaconda3/envs/vseek-vllm/lib/python3.11/site-packages/pyarrow/parquet/core.py:1538, in ParquetDataset.read(self, columns, use_threads, use_pandas_metadata)
#    1530         index_columns = [
#    1531             col for col in _get_pandas_index_columns(metadata)
#    1532             if not isinstance(col, dict)
#    1533         ]
#    1534         columns = (
#    1535             list(columns) + list(set(index_columns) - set(columns))
#    1536         )
# -> 1538 table = self._dataset.to_table(
#    1539     columns=columns, filter=self._filter_expression,
#    1540     use_threads=use_threads
#    1541 )
#    1543 # if use_pandas_metadata, restore the pandas metadata (which gets
#    1544 # lost if doing a specific `columns` selection in to_table)
#    1545 if use_pandas_metadata:
#
# File ~/anaconda3/envs/vseek-vllm/lib/python3.11/site-packages/pyarrow/_dataset.pyx:589, in pyarrow._dataset.Dataset.to_table()
#
# File ~/anaconda3/envs/vseek-vllm/lib/python3.11/site-packages/pyarrow/_dataset.pyx:3939, in pyarrow._dataset.Scanner.to_table()
#
# File ~/anaconda3/envs/vseek-vllm/lib/python3.11/site-packages/pyarrow/error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File ~/anaconda3/envs/vseek-vllm/lib/python3.11/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowNotImplementedError: Nested data conversions not implemented for chunked array outputs

# %%
import pandas as pd
test_df = pd.read_parquet(f"/nas/mars/vseek/data/tagsummary/test.parquet")

test_df[0]
# Out:
#   data_source                                             prompt  \
# 0         lvb  [{'content': '
# You are a video analysis agent ...
# 1         lvb  [{'content': '
# You are a video analysis agent ...
# 2         lvb  [{'content': '
# You are a video analysis agent ...
# 3         lvb  [{'content': '
# You are a video analysis agent ...
# 4         lvb  [{'content': '
# You are a video analysis agent ...
#
#            ability                                   reward_model  \
# 0  video_reasoning  {'ground_truth': '2', 'style': 'exact_match'}
# 1  video_reasoning  {'ground_truth': '2', 'style': 'exact_match'}
# 2  video_reasoning  {'ground_truth': '0', 'style': 'exact_match'}
# 3  video_reasoning  {'ground_truth': '4', 'style': 'exact_match'}
# 4  video_reasoning  {'ground_truth': '2', 'style': 'exact_match'}
#
#                                           extra_info
# 0  {'candidates': ['[applause] and Seye Seye Seye...
# 1  {'candidates': ['still blanketed darkness与othe...
# 2  {'candidates': ['we've got the cookies and the...
# 3  {'candidates': ['before the time of the pandem...
# 4  {'candidates': ['friend', 'my life is full of ...

# %%
test_df['extra_info'][0]
# Out:
# {'candidates': array(['[applause] and Seye Seye Seye Seye Seye',
#         '[applause] and my love that I made on the ke is',
#         'captain of the godson, three three three three three three and my love that I made on the ke is',
#         '[applause] and captain of the godson, three three three three three three'],
#        dtype=object),
#  'correct_choice': '2',
#  'index': 0,
#  'metadata': {'id': '86CxyhFV9MI_1',
#   'original_data': '{"video_id": "86CxyhFV9MI", "question": "Which subtitles appear at the same time as the gray-haired man in the black shirt on stage in the video?", "question_wo_referring_query": "Which subtitles appear simultaneously?", "candidates": ["[applause] and Seye Seye Seye Seye Seye", "[applause] and my love that I made on the ke is", "captain of the godson, three three three three three three and my love that I made on the ke is", "[applause] and captain of the godson, three three three three three three"], "correct_choice": 2, "position": [353, 1981, 3899], "topic_category": "NP-News-Programs", "question_category": "TOS", "level": "L2-Relation", "id": "86CxyhFV9MI_1", "video_path": "86CxyhFV9MI.mp4", "subtitle_path": "86CxyhFV9MI_en.json", "duration_group": 600, "starting_timestamp_for_subtitles": 0, "duration": 190.16, "view_count": 259852}',
#   'video_id': '86CxyhFV9MI'},
#  'paths': {'raw_video_path': '/nas/mars/dataset/longvideobench/LongVideoBench/videos/86CxyhFV9MI.mp4',
#   'subtitle_path': '/nas/mars/dataset/longvideobench/LongVideoBench/subtitles/86CxyhFV9MI_en.json',
#   'video_path': '/nas/mars/dataset/longvideobench/burn-subtitles/86CxyhFV9MI.mp4'},
#  'question': '\n This is a multiple choice question. You must choose the correct answer as a number or letter of the option. \nQuestion: Which subtitles appear at the same time as the gray-haired man in the black shirt on stage in the video? \n',
#  'split': 'test',
#  'tools_kwargs': {'video_search': {'execute_kwargs': {'dataset': 'lvb',
#     'precomputed_frames': array([{'encoded_frames': array(['...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...'],
#                  dtype=object), 'window_idx': 0}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
#            {'encoded_frames': array(['...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...'],
#                  dtype=object), 'window_idx': 1}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
#            {'encoded_frames': array(['...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...'],
#                  dtype=object), 'window_idx': 2}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
#            {'encoded_frames': array(['...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...'],
#                  dtype=object), 'window_idx': 3}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
#            {'encoded_frames': array(['...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...'],
#                  dtype=object), 'window_idx': 4}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
#            {'encoded_frames': array(['...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...'],
#                  dtype=object), 'window_idx': 5}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
#            {'encoded_frames': array(['...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...'],
#                  dtype=object), 'window_idx': 6}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
#            {'encoded_frames': array(['...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...'],
#                  dtype=object), 'window_idx': 7}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
#            {'encoded_frames': array(['...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...'],
#                  dtype=object), 'window_idx': 8}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
#            {'encoded_frames': array(['...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...'],
#                  dtype=object), 'window_idx': 9}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
#            {'encoded_frames': array(['...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...'],
# ...
#            {'encoded_frames': array(['...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...'],
#                  dtype=object), 'window_idx': 21}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
#            {'encoded_frames': array(['...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...'],
#                  dtype=object), 'window_idx': 22}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
#            {'encoded_frames': array(['...',
#                   '...',
#                   '...',
#                   '...',
#                   '...',
#                   '...'],
#                  dtype=object), 'window_idx': 23}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
#           dtype=object),
#     'puls': {'proposition': array(['gray_haired_man_in_black_shirt_on_stage'], dtype=object),
#      'specification': 'subtitle appears at the same time as "gray_haired_man_in_black_shirt_on_stage"'},
#     'topk': 4,
#     'video_id': '86CxyhFV9MI',
#     'video_summary': array(['...',
#            '...',
#            '...',
#            '...',
#            '...',
#            '...',
#            '...',
#            '...',
#            '...',
#            '...',
#            '...',
#            '...',
#            '...',
#            '...',
#            '...',
#            '...'],
#           dtype=object)}}}}
